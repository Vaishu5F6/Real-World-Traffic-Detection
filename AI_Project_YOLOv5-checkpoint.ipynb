# %%
from ultralytics import YOLO
from pathlib import Path
from PIL import Image, ImageEnhance
import numpy as np

import torch

# %%
model = YOLO('yolov5n.yaml').load('yolov5nu.pt')
yaml_path = Path('./dataset/data.yaml').resolve()
results = model.train(data=str(yaml_path), epochs=60, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1      1760  ultralytics.nn.modules.conv.Conv             [3, 16, 6, 2, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      4800  ultralytics.nn.modules.block.C3              [32, 32, 1]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     29184  ultralytics.nn.modules.block.C3              [64, 64, 2]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  3    156928  ultralytics.nn.modules.block.C3              [128, 128, 3]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    296448  ultralytics.nn.modules.block.C3              [256, 256, 1]
# ...

# %%
# model = YOLO(str(Path('./runs/detect/train4/weights/best.pt').resolve()))

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.208  Python-3.11.1 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv5n summary (fused): 193 layers, 2503919 parameters, 0 gradients, 7.1 GFLOPs
# val: Scanning C:\Rahul\Classwork\Sem2_Fall2023\AI\YOLOv8\dataset\valid\labels.cache... 279 images, 9 backgrounds, 0 cor
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:06
#                    all        279       3188      0.941      0.867       0.94      0.721
#                bicycle        279        134      0.977      0.903      0.967      0.766
#                    bus        279         41      0.939      0.927      0.974      0.861
#                    car        279       1911      0.942      0.919      0.963       0.77
#              motorbike        279        650       0.94      0.795      0.899      0.603
#                 person        279        452       0.91      0.792      0.896      0.606
# ...

# %%
conf_mat = metrics.confusion_matrix
total_events = sum(sum(conf_mat.matrix))

tp, fp = conf_mat.tp_fp()
accuracy = sum(tp) / total_events
accuracy
# Out:
# 0.8005405405405406

# %%
# model = YOLO(str(Path('./runs/detect/train6/weights/best.pt').resolve()))

# %%
# predict_img_path = Path('C:/Rahul/Classwork/Sem2_Fall2023/AI/YOLOv8/dataset/test/images/screenshot_9107_jpg.rf.782d31661392533d00f4947795444496.jpg')

# %%
# predict_img_path2 = Path('C:/Rahul/Classwork/Sem2_Fall2023/AI/YOLOv8/dataset/test/images/duque_de_caxias-980_png_jpg.rf.2ea941ebca6001a8330ea30d471d5b33.jpg')

# %%
# results = model.predict(predict_img_path2, imgsz=640, save=True, conf=0.65)
# Out:
# image 1/1 C:\Rahul\Classwork\Sem2_Fall2023\AI\YOLOv8\dataset\test\images\duque_de_caxias-980_png_jpg.rf.2ea941ebca6001a8330ea30d471d5b33.jpg: 640x640 1 bicycle, 3 cars, 3 motorbikes, 2 persons, 29.9ms
# Speed: 1035.5ms preprocess, 29.9ms inference, 4.2ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3

# %%
# Image.open(Path(f'./runs/detect/predict3/{predict_img_path.name}'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# img = Image.open(Path(f'./runs/detect/predict3/{predict_img_path2.name}'))
# img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# img.close()
