# %%
from ultralytics import YOLO
from pathlib import Path
from PIL import Image, ImageEnhance
import numpy as np

import torch
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from ultralytics import YOLO
#       2 from pathlib import Path
#       3 from PIL import Image, ImageEnhance
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\__init__.py:5
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
#       3 __version__ = '8.0.208'
# ----> 5 from ultralytics.models import RTDETR, SAM, YOLO
#       6 from ultralytics.models.fastsam import FastSAM
#       7 from ultralytics.models.nas import NAS
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\ultralytics\models\__init__.py:3
#       1 # Ultralytics YOLO 🚀, AGPL-3.0 license
# ----> 3 from .rtdetr import RTDETR
#       4 from .sam import SAM
#       5 from .yolo import YOLO
#
# ...

# %%
# Set up label encodings and data paths

label_encodings = ['bicycle', 'bus', 'car', 'motorbike', 'person']
data_paths = {
    "train": {
        "images": Path("./dataset/train/images"),
        "labels": Path("./dataset/train/labels"),
    },
    "test": {
        "images": Path("./dataset/test/images"),
        "labels": Path("./dataset/test/labels"),
    },
    "val": {
        "images": Path("./dataset/val/images"),
        "labels": Path("./dataset/val/labels"),
    },
}

# %%
model = YOLO('yolov8n.yaml').load('yolov8n.pt')
yaml_path = Path('./dataset/data.yaml').resolve()
results = model.train(data=str(yaml_path), epochs=60, imgsz=640)
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# results = model.train(data=str(yaml_path), epochs=60, batch=32, imgsz=640, resume=True)

# %%
metrics = model.val()
# Out:
# Ultralytics YOLOv8.0.208  Python-3.11.1 torch-2.1.2+cu118 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
# YOLOv8n summary (fused): 168 layers, 3006623 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning C:\Rahul\Classwork\Sem2_Fall2023\AI\YOLOv8\dataset\valid\labels.cache... 279 images, 9 backgrounds, 0 cor
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 18/18 [00:05
#                    all        279       3188      0.928      0.893       0.94      0.732
#                bicycle        279        134      0.923      0.918      0.964      0.782
#                    bus        279         41      0.947      0.976      0.984      0.861
#                    car        279       1911      0.927      0.928       0.96      0.783
#              motorbike        279        650      0.934      0.832      0.905      0.604
#                 person        279        452      0.906       0.81      0.887       0.63
# ...

# %%
conf_mat = metrics.confusion_matrix
total_events = sum(sum(conf_mat.matrix))

tp, fp = conf_mat.tp_fp()
accuracy = sum(tp) / total_events
accuracy
# Out:
# 0.8203493207651789

# %%
# model = YOLO(str(Path('./runs/detect/train13/weights/best.pt').resolve()))

# %%
# predict_img_path = np.random.choice([path.resolve() for path in data_paths['test']['images'].rglob('*')], size=1)

# %%
# predict_img_path
# Out:
# array([WindowsPath('C:/Rahul/Classwork/Sem2_Fall2023/AI/YOLOv8/dataset/test/images/screenshot_9107_jpg.rf.782d31661392533d00f4947795444496.jpg')], dtype=object)

# %%
# results = model.predict(predict_img_path[0], imgsz=640, save=True, conf=0.65)
# Out:
# image 1/1 C:\Rahul\Classwork\Sem2_Fall2023\AI\YOLOv8\dataset\test\images\screenshot_9107_jpg.rf.782d31661392533d00f4947795444496.jpg: 640x640 3 bicycles, 15 cars, 1 motorbike, 1 person, 24.1ms
# Speed: 1054.7ms preprocess, 24.1ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict2

# %%
# Image.open(Path(f'./runs/detect/predict2/{predict_img_path[0].name}'))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x640>

# %%
# predict_img_path2 = Path('C:/Rahul/Classwork/Sem2_Fall2023/AI/YOLOv8/dataset/predict2/duque_de_caxias-980_png_jpg.rf.2ea941ebca6001a8330ea30d471d5b33.jpg')

# %%
# img = Image.open(Path(f'./runs/detect/predict2/{predict_img_path2.name}'))
# # img
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img = Image.open(Path(f'./runs/detect/predict2/{predict_img_path2.name}'))
#       2 img
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\PIL\Image.py:3227, in open(fp, mode, formats)
#    3224     filename = fp
#    3226 if filename:
# -> 3227     fp = builtins.open(filename, "rb")
#    3228     exclusive_fp = True
#    3230 try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Rahul\\Classwork\\Sem2_Fall2023\\AI\\YOLOv8\\runs\\detect\\predict2\\duque_de_caxias-980_png_jpg.rf.2ea941ebca6001a8330ea30d471d5b33.jpg'
